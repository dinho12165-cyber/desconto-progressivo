# %% [markdown]
# <a href="https://colab.research.google.com/github/dinho12165-cyber/desconto-progressivo/blob/main/Nunes_Ag6_DS_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Entrada  dos dados: solicito que o cliente que digite o valor da compra para verificar a qual desconto ele tem direito
valor_total = float(input("digite o valor da compra"))
if valor_total < 200:
  print("voce tem desconto de valor_total * 0.05")
elif valor_total < 300:
  print("voce tem desconto de valor_total * 0.10")
else:
  print("voce tem desconto de valor_total * 0.15")


## aqui as variaveis: compra, o desconto e o valor a pagar
compra = float(input("digite valor da compra"))

desconto = float(input("digite valor do desconto"))
pagar = float(input("digite valor a pagar"))

print("compra,desconto,pagar")

compra = 190
desconto = 00.5
pagar = (compra * 00.5)/100

# aqui a saida

print("compra,desconto,pagar")
# Out:
# digite o valor da compra  190
# voce tem desconto de valor_total * 0.05
# digite valor da compra    250
# digite valor do desconto   00.5
# digite valor a pagar  180.5
# compra,desconto,pagar
