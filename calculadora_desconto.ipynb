# %% [markdown]
# <a href="https://colab.research.google.com/github/dinho12165-cyber/desconto-progressivo/blob/main/calculadora_desconto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
compra = 190
desconto = (compra * 5)/100
pagar = (compra - desconto)
print(compra, desconto,pagar)

compra = 250
desconto = (compra * 10)/100
pagar = (compra - desconto)
print(compra, desconto,pagar)

compra = 350
desconto = (compra * 15)/100
pagar = (compra - desconto)
print(compra, desconto,pagar)
# Out:
# 190 9.5 180.5
# 250 25.0 225.0
# 350 52.5 297.5
